# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/raumuong.jpg'

# %%
# Đọc ảnh 
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
# Kích thước ban đầu:
print(img.size)
# Out:
# (275, 183)

# %%
# Thay đổi kích thước
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
img.save('C:/Users/Admin/Documents/raumuong2.JPG')

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x33>

# %%
img.save('C:/Users/Admin/Documents/raumuong3.JPG')
