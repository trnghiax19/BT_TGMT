# %%
#!pip install matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
my_path = 'C:/Users/sgb-msi.jpg'

# %%
im = Image.open(my_path)
plt.imshow(im)

# %%
x = [1, 2, 3, 4, 5]
y = [10, 15, 20, 25, 30]
plt.plot(x,y, color="blue")
plt.title("Vẽ biểu đồ cơ bản")
plt.axis('off')
plt.show()

# %%
x = [100, 200, 300, 400]
y = [200, 300, 200, 300]

plt.imshow(im)
plt.plot(x,y, 'bo--')
plt.show()
